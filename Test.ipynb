# %% [markdown]
# Remove test data before (If it exists)

# %%
import os
os.remove("test.txt")
os.remove("test.csv")

# %% [markdown]
# Test with subt.srt (Subtitles Artificial Intelligence film)

# %%
run srt_to_csv.py test.srt test.csv
